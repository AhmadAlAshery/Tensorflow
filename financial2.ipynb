# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadAlAshery/Tensorflow/blob/main/financial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The financial analysis

# %%
# import libraries which will be used 
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import zipfile;

# %%
url_genting = 'https://drive.google.com/file/d/1VVzjd8UBXOyh4Lp43hS-TtALgO7aZvPL/view?usp=sharing'
path_genting = 'https://drive.google.com/uc?export=download&id='+url_genting.split('/')[-2]

url_airline = 'https://drive.google.com/file/d/1kd-Yf6Ss1R1_1DG5kTUaMgCNnBNjJQWr/view?usp=sharing'
path_airline = 'https://drive.google.com/uc?export=download&id='+url_airline.split('/')[-2]

url_jard = 'https://drive.google.com/file/d/1-oi2XjWKU1_jBiuaBvbJuQbruKYx4Qgf/view?usp=sharing'
path_jard = 'https://drive.google.com/uc?export=download&id='+url_jard.split('/')[-2]

url_cortina = "https://drive.google.com/file/d/1HE_8HIf0pVX_1xPAdYmKtskRVdCYJSTm/view?usp=sharing"
path_cortina = 'https://drive.google.com/uc?export=download&id='+url_cortina.split('/')[-2]

url_fux = "https://drive.google.com/file/d/1BsA9sC5MfLy0XS0n2edMzF0zFihqs8IG/view?usp=sharing"
path_fux = 'https://drive.google.com/uc?export=download&id='+url_fux.split('/')[-2]

url_health = "https://drive.google.com/file/d/1-l4oQwe7NhjBDW3AdDfwNNsTz9681NY8/view?usp=sharing"
path_health = 'https://drive.google.com/uc?export=download&id='+url_health.split('/')[-2]

url_mem = "https://drive.google.com/file/d/10K37xxAJ4FeqUY-4ajeCryhnOlV2t4Hy/view?usp=sharing"
path_mem = 'https://drive.google.com/uc?export=download&id='+url_mem.split('/')[-2]

url_park = "https://drive.google.com/file/d/1EmADgkb2q_WkywdbSA5qSpZPAap3FBlJ/view?usp=sharing"
path_park = 'https://drive.google.com/uc?export=download&id='+url_park.split('/')[-2]

url_pav = "https://drive.google.com/file/d/1xnSiVi6HDevjqa9SNc1zZNBNK1ftRZHJ/view?usp=sharing"
path_pav = 'https://drive.google.com/uc?export=download&id='+url_pav.split('/')[-2]

url_uni = "https://drive.google.com/file/d/1ICFKblYjouXy4ucc59E0Vcv-0OGARR68/view?usp=sharing"
path_uni = 'https://drive.google.com/uc?export=download&id='+url_uni.split('/')[-2]

# %%
import zipfile
with zipfile.ZipFile("drive-download-20220917T132632Z-001.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
ls
# Out:
# '10 Uni-Asia Group Limited CHJ.SI.csv'
# '1 Singapore Genting G13.SI.csv'
# '2 Singapore Airlines C6L.SI.csv'
# '3 Jardine Cycle _ Carriage Limited  C07.SI.csv'
# '4 Cortina Holdings Limited C41.SI.csv'
# '5 Fuxing China Group Limited AWK.SI.csv'
# '6 HealthBank Holdings Limited  40B.SI.csv'
# '7 Memories Group Limited 1H4.SI.csv'
# '8 Parkson Retail Asia Limited O9E.SI.csv'
# '9 Pavillon Holdings Ltd 596.SI.csv'
#  a.h5py
#  drive-download-20220917T132632Z-001.zip
#  sample_data/

# %%
# load datasets into dataframs
genting_1 = pd.read_csv('1 Singapore Genting G13.SI.csv', parse_dates=['Date'])
airline_2 = pd.read_csv('2 Singapore Airlines C6L.SI.csv', parse_dates=['Date'])
jardine_3 = pd.read_csv('3 Jardine Cycle _ Carriage Limited  C07.SI.csv', parse_dates=['Date'])
cortina_4 = pd.read_csv('4 Cortina Holdings Limited C41.SI.csv', parse_dates=['Date'])
fux_5 = pd.read_csv('5 Fuxing China Group Limited AWK.SI.csv', parse_dates=['Date'])
health_6 = pd.read_csv('6 HealthBank Holdings Limited  40B.SI.csv', parse_dates=['Date'])
mem_7 = pd.read_csv('7 Memories Group Limited 1H4.SI.csv', parse_dates=['Date'])
park_8 = pd.read_csv('8 Parkson Retail Asia Limited O9E.SI.csv', parse_dates=['Date'])
pav_9 = pd.read_csv('9 Pavillon Holdings Ltd 596.SI.csv', parse_dates=['Date'])
uni_10 = pd.read_csv('10 Uni-Asia Group Limited CHJ.SI.csv', parse_dates=['Date'])

# %%
data = {0:genting_1,
        1:airline_2,
        2:jardine_3,
        3:cortina_4,
        4:fux_5,
        5:health_6,
        6:mem_7,
        7:park_8,
        8:pav_9,
        9:uni_10}

data_names = {0:'Singapore Genting G13.SI',
        1:'Singapore Airlines C6L.SI',
        2:'Jardine Cycle & Carriage Limited  C07.SI',
        3:'Cortina Holdings Limited C41.SI',
        4:'Fuxing China Group Limited AWK.SI',
        5:'HealthBank Holdings Limited  40B.SI',
        6:'Memories Group Limited 1H4.SI',
        7:'Parkson Retail Asia Limited O9E.SI',
        8:'Pavillon Holdings Ltd 596.SI',
        9:'Uni-Asia Group Limited CHJ.SI'}

# %%
for i in range(10):
    data[i].dropna(inplace=True)

# %%
# visualize the change in stoke price over time in each company

for i in range(10):
    plt.figure(figsize=(20,20))
    plt.subplot(10,1,i+1)
    plt.plot(data[i]["Date"], data[i]['Close'], label=data_names[i])
    plt.xlabel('Time')
    plt.ylabel("Stoke Price Close (SGD)")
    plt.legend()
    plt.show()

# %%
sample_len = len(data[0])
train_len = int(np.ceil(sample_len*0.8)) 
test_len = sample_len - train_len
sample_len, train_len, test_len
# Out:
# (1435, 1148, 287)

# %%
df_train = pd.DataFrame(data[0].sample(train_len, ignore_index=True)) 
df_test = pd.DataFrame(data[0].tail(test_len))

# %%
data[0].drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
for i in range(1,10):
    data[i].drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
    df_train = pd.concat([df_train, pd.DataFrame(data[i].sample(train_len, ignore_index=True))])
    df_test = pd.concat([df_test, pd.DataFrame(data[i].tail(test_len))])

# %%
df_train.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
df_test.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11480 entries, 0 to 1147
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    11480 non-null  datetime64[ns]
#  1   Close   11480 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 269.1 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2870 entries, 1148 to 1434
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2870 non-null   datetime64[ns]
#  1   Close   2870 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 67.3 KB

# %%
scaler = MinMaxScaler()

# %%
df_train[['Close']] = scaler.fit_transform(df_train[['Close']])

# %%
df_train.tail()
# Out:
#            Date     Close
# 1143 2018-07-09  0.017957
# 1144 2021-06-03  0.016155
# 1145 2021-06-08  0.015531
# 1146 2021-03-12  0.011893
# 1147 2018-10-01  0.017818

# %%
training_data = df_train[['Close']].values

# %%
training_data.shape
# Out:
# (11480, 1)

# %%
x_train = []
y_train = []
for i in range(60, len(training_data)):
    x_train.append(training_data[i-60:i, :])
    y_train.append(training_data[i,:])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape, y_train.shape
# Out:
# ((11420, 60, 1), (11420, 1))

# %%
model  = tf.keras.Sequential([
    tf.keras.layers.LSTM(100, return_sequences=True, input_shape=(60, 1)),
    tf.keras.layers.SimpleRNN(100, return_sequences=False),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9),
              metrics=["mae"])

# %%
history = model.fit(x_train, y_train, epochs=100, callbacks=[tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-7 * 10**(epoch / 30))])
# Out:
# Epoch 1/100
# 357/357 [==============================] - 28s 71ms/step - loss: 0.0685 - mae: 0.1691 - lr: 1.0000e-07
# Epoch 2/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0672 - mae: 0.1666 - lr: 1.0798e-07
# Epoch 3/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0660 - mae: 0.1672 - lr: 1.1659e-07
# Epoch 4/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0650 - mae: 0.1693 - lr: 1.2589e-07
# Epoch 5/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0640 - mae: 0.1714 - lr: 1.3594e-07
# Epoch 6/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0630 - mae: 0.1734 - lr: 1.4678e-07
# Epoch 7/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0621 - mae: 0.1750 - lr: 1.5849e-07
# Epoch 8/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0611 - mae: 0.1762 - lr: 1.7113e-07
# Epoch 9/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0601 - mae: 0.1771 - lr: 1.8478e-07
# Epoch 10/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0590 - mae: 0.1776 - lr: 1.9953e-07
# Epoch 11/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0580 - mae: 0.1777 - lr: 2.1544e-07
# Epoch 12/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0569 - mae: 0.1775 - lr: 2.3263e-07
# Epoch 13/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0558 - mae: 0.1768 - lr: 2.5119e-07
# Epoch 14/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0547 - mae: 0.1757 - lr: 2.7123e-07
# Epoch 15/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0537 - mae: 0.1744 - lr: 2.9286e-07
# Epoch 16/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0526 - mae: 0.1727 - lr: 3.1623e-07
# Epoch 17/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0514 - mae: 0.1706 - lr: 3.4145e-07
# Epoch 18/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0503 - mae: 0.1683 - lr: 3.6869e-07
# Epoch 19/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0490 - mae: 0.1658 - lr: 3.9811e-07
# Epoch 20/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0478 - mae: 0.1629 - lr: 4.2987e-07
# Epoch 21/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0464 - mae: 0.1600 - lr: 4.6416e-07
# Epoch 22/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0451 - mae: 0.1567 - lr: 5.0119e-07
# Epoch 23/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0438 - mae: 0.1535 - lr: 5.4117e-07
# Epoch 24/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0424 - mae: 0.1502 - lr: 5.8434e-07
# Epoch 25/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0410 - mae: 0.1470 - lr: 6.3096e-07
# Epoch 26/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0395 - mae: 0.1436 - lr: 6.8129e-07
# Epoch 27/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0380 - mae: 0.1400 - lr: 7.3564e-07
# Epoch 28/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0366 - mae: 0.1356 - lr: 7.9433e-07
# Epoch 29/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0353 - mae: 0.1309 - lr: 8.5770e-07
# Epoch 30/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0342 - mae: 0.1256 - lr: 9.2612e-07
# Epoch 31/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0331 - mae: 0.1203 - lr: 1.0000e-06
# Epoch 32/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0321 - mae: 0.1150 - lr: 1.0798e-06
# Epoch 33/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0312 - mae: 0.1103 - lr: 1.1659e-06
# Epoch 34/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0303 - mae: 0.1065 - lr: 1.2589e-06
# Epoch 35/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0294 - mae: 0.1027 - lr: 1.3594e-06
# Epoch 36/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0285 - mae: 0.0986 - lr: 1.4678e-06
# Epoch 37/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0277 - mae: 0.0944 - lr: 1.5849e-06
# Epoch 38/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0269 - mae: 0.0916 - lr: 1.7113e-06
# Epoch 39/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0261 - mae: 0.0900 - lr: 1.8478e-06
# Epoch 40/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0253 - mae: 0.0886 - lr: 1.9953e-06
# Epoch 41/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0245 - mae: 0.0873 - lr: 2.1544e-06
# Epoch 42/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0238 - mae: 0.0860 - lr: 2.3263e-06
# Epoch 43/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0231 - mae: 0.0850 - lr: 2.5119e-06
# Epoch 44/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0225 - mae: 0.0840 - lr: 2.7123e-06
# Epoch 45/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0219 - mae: 0.0835 - lr: 2.9286e-06
# Epoch 46/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0214 - mae: 0.0833 - lr: 3.1623e-06
# Epoch 47/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0208 - mae: 0.0834 - lr: 3.4145e-06
# Epoch 48/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0203 - mae: 0.0832 - lr: 3.6869e-06
# Epoch 49/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0197 - mae: 0.0828 - lr: 3.9811e-06
# Epoch 50/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0192 - mae: 0.0824 - lr: 4.2987e-06
# Epoch 51/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0186 - mae: 0.0815 - lr: 4.6416e-06
# Epoch 52/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0180 - mae: 0.0797 - lr: 5.0119e-06
# Epoch 53/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0174 - mae: 0.0777 - lr: 5.4117e-06
# Epoch 54/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0168 - mae: 0.0749 - lr: 5.8434e-06
# Epoch 55/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0161 - mae: 0.0719 - lr: 6.3096e-06
# Epoch 56/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0154 - mae: 0.0697 - lr: 6.8129e-06
# Epoch 57/100
# 357/357 [==============================] - 22s 63ms/step - loss: 0.0147 - mae: 0.0673 - lr: 7.3564e-06
# Epoch 58/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0140 - mae: 0.0646 - lr: 7.9433e-06
# Epoch 59/100
# 357/357 [==============================] - 22s 63ms/step - loss: 0.0132 - mae: 0.0624 - lr: 8.5770e-06
# Epoch 60/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0125 - mae: 0.0597 - lr: 9.2612e-06
# Epoch 61/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0117 - mae: 0.0574 - lr: 1.0000e-05
# Epoch 62/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0109 - mae: 0.0548 - lr: 1.0798e-05
# Epoch 63/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0102 - mae: 0.0525 - lr: 1.1659e-05
# Epoch 64/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0094 - mae: 0.0502 - lr: 1.2589e-05
# Epoch 65/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0087 - mae: 0.0483 - lr: 1.3594e-05
# Epoch 66/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0081 - mae: 0.0465 - lr: 1.4678e-05
# Epoch 67/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0074 - mae: 0.0443 - lr: 1.5849e-05
# Epoch 68/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0068 - mae: 0.0424 - lr: 1.7113e-05
# Epoch 69/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0062 - mae: 0.0410 - lr: 1.8478e-05
# Epoch 70/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0057 - mae: 0.0393 - lr: 1.9953e-05
# Epoch 71/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0053 - mae: 0.0375 - lr: 2.1544e-05
# Epoch 72/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0049 - mae: 0.0365 - lr: 2.3263e-05
# Epoch 73/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0046 - mae: 0.0359 - lr: 2.5119e-05
# Epoch 74/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0043 - mae: 0.0357 - lr: 2.7123e-05
# Epoch 75/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0040 - mae: 0.0353 - lr: 2.9286e-05
# Epoch 76/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0038 - mae: 0.0347 - lr: 3.1623e-05
# Epoch 77/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0037 - mae: 0.0342 - lr: 3.4145e-05
# Epoch 78/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0035 - mae: 0.0335 - lr: 3.6869e-05
# Epoch 79/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0034 - mae: 0.0325 - lr: 3.9811e-05
# Epoch 80/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0032 - mae: 0.0319 - lr: 4.2987e-05
# Epoch 81/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0031 - mae: 0.0317 - lr: 4.6416e-05
# Epoch 82/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0030 - mae: 0.0313 - lr: 5.0119e-05
# Epoch 83/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0030 - mae: 0.0306 - lr: 5.4117e-05
# Epoch 84/100
# 357/357 [==============================] - 22s 62ms/step - loss: 0.0029 - mae: 0.0309 - lr: 5.8434e-05
# Epoch 85/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0029 - mae: 0.0311 - lr: 6.3096e-05
# Epoch 86/100
# 357/357 [==============================] - 22s 61ms/step - loss: 0.0028 - mae: 0.0300 - lr: 6.8129e-05
# Epoch 87/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0028 - mae: 0.0305 - lr: 7.3564e-05
# Epoch 88/100
# 357/357 [==============================] - 24s 68ms/step - loss: 0.0028 - mae: 0.0305 - lr: 7.9433e-05
# Epoch 89/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0027 - mae: 0.0298 - lr: 8.5770e-05
# Epoch 90/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0026 - mae: 0.0293 - lr: 9.2612e-05
# Epoch 91/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0026 - mae: 0.0289 - lr: 1.0000e-04
# Epoch 92/100
# 357/357 [==============================] - 24s 66ms/step - loss: 0.0026 - mae: 0.0296 - lr: 1.0798e-04
# Epoch 93/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0025 - mae: 0.0288 - lr: 1.1659e-04
# Epoch 94/100
# 357/357 [==============================] - 24s 66ms/step - loss: 0.0025 - mae: 0.0291 - lr: 1.2589e-04
# Epoch 95/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0024 - mae: 0.0282 - lr: 1.3594e-04
# Epoch 96/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0024 - mae: 0.0283 - lr: 1.4678e-04
# Epoch 97/100
# 357/357 [==============================] - 24s 66ms/step - loss: 0.0023 - mae: 0.0281 - lr: 1.5849e-04
# Epoch 98/100
# 357/357 [==============================] - 24s 66ms/step - loss: 0.0023 - mae: 0.0281 - lr: 1.7113e-04
# Epoch 99/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0022 - mae: 0.0283 - lr: 1.8478e-04
# Epoch 100/100
# 357/357 [==============================] - 23s 66ms/step - loss: 0.0022 - mae: 0.0282 - lr: 1.9953e-04

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-3, -0.25, 0.25])
# Out:
# (1e-08, 0.001, -0.25, 0.25)

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=["mae"])

# %%
history_2 = model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 357/357 [==============================] - 26s 63ms/step - loss: 0.0022 - mae: 0.0273
# Epoch 2/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0022 - mae: 0.0269
# Epoch 3/100
# 357/357 [==============================] - 23s 63ms/step - loss: 0.0021 - mae: 0.0268
# Epoch 4/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0271
# Epoch 5/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0267
# Epoch 6/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0269
# Epoch 7/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0266
# Epoch 8/100
# 357/357 [==============================] - 23s 63ms/step - loss: 0.0021 - mae: 0.0273
# Epoch 9/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0268
# Epoch 10/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0266
# Epoch 11/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0262
# Epoch 12/100
# 357/357 [==============================] - 23s 63ms/step - loss: 0.0021 - mae: 0.0265
# Epoch 13/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0263
# Epoch 14/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0263
# Epoch 15/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0021 - mae: 0.0271
# Epoch 16/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0261
# Epoch 17/100
# 357/357 [==============================] - 24s 68ms/step - loss: 0.0020 - mae: 0.0263
# Epoch 18/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0265
# Epoch 19/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0264
# Epoch 20/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 21/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0262
# Epoch 22/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0265
# Epoch 23/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0262
# Epoch 24/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 25/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0259
# Epoch 26/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0263
# Epoch 27/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 28/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0262
# Epoch 29/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0259
# Epoch 30/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0258
# Epoch 31/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0020 - mae: 0.0262
# Epoch 32/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0263
# Epoch 33/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 34/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 35/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0259
# Epoch 36/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0261
# Epoch 37/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0261
# Epoch 38/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0258
# Epoch 39/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0258
# Epoch 40/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0261
# Epoch 41/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 42/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0261
# Epoch 43/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0257
# Epoch 44/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0020 - mae: 0.0259
# Epoch 45/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0020 - mae: 0.0256
# Epoch 46/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0262
# Epoch 47/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0258
# Epoch 48/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 49/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0258
# Epoch 50/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 51/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 52/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 53/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0258
# Epoch 54/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 55/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0258
# Epoch 56/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0259
# Epoch 57/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 58/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 59/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 60/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0254
# Epoch 61/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 62/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 63/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0260
# Epoch 64/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 65/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 66/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 67/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 68/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 69/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 70/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 71/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 72/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0253
# Epoch 73/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0254
# Epoch 74/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 75/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 76/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 77/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 78/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 79/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 80/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0258
# Epoch 81/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 82/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 83/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 84/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 85/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 86/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 87/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 88/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 89/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0253
# Epoch 90/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 91/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 92/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 93/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0254
# Epoch 94/100
# 357/357 [==============================] - 23s 65ms/step - loss: 0.0019 - mae: 0.0256
# Epoch 95/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0254
# Epoch 96/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0257
# Epoch 97/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0254
# Epoch 98/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0255
# Epoch 99/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0253
# Epoch 100/100
# 357/357 [==============================] - 23s 64ms/step - loss: 0.0019 - mae: 0.0253

# %%
plt.plot(history_2.history['mae'])

# %%
plt.plot(history_2.history['loss'])

# %%
df_test["Close"].values.shape
# Out:
# (2870,)

# %%
testing_data = df_test["Close"].values.reshape(-1,1)
testing_data.shape
# Out:
# (2870, 1)

# %%
x_test = []
y_test = []
for i in range(60, len(testing_data)):
    x_test.append(testing_data[i-60:i, :])
    y_test.append(testing_data[i,:])

# %%
#x_test = []
#y_test = df_test["close"]
#for i in range(60, len(testing_data)):
#    x_test.append(testing_data[i-60:i,0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test = x_test.reshape(-1,60,1)

# %%
x_test.shape, y_test.shape, x_train.shape
# Out:
# ((2810, 60, 1), (2810, 1), (11420, 60, 1))

# %%
model  = tf.keras.models.load_model('a.h5py')

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
RMSE = np.sqrt(np.mean(predictions-y_test)**2)
RMSE
# Out:
# 2.820929435285934

# %%
x = []
for i in range(10):
    test = scaler.fit_transform(data[i]["Close"].values.reshape(-1,1))[1148-60:,:]
    test_y = scaler.fit_transform(data[i]["Close"].values.reshape(-1,1))[1148:,:]
    test_x =[]
    for i in range(60, len(test)):
        test_x.append(test[i-60:i,0])
    pred = model.predict(np.array(test_x))
    pred = scaler.inverse_transform(pred)
    arr=np.full((1148,1),np.nan)
    x.append(np.concatenate((arr, pred), axis=0).reshape(-1,1))

# %%
for i in range(10):
    data[i]["Pred"] = x[i]

# %%
data[0].tail()
# Out:
#            Date  Close      Pred
# 1430 2022-09-09  0.770  0.815938
# 1431 2022-09-12  0.775  0.813860
# 1432 2022-09-13  0.790  0.811758
# 1433 2022-09-14  0.785  0.809889
# 1434 2022-09-15  0.795  0.808258

# %%
for i in range(10):
    plt.figure(figsize=(20,20))
    plt.subplot(10,1,i+1)
    plt.plot(data[i]["Date"], data[i]['Close'], label='original'+data_names[i])
    plt.plot(data[i]["Date"], data[i]["Pred"], color='r', label='prediction')
    plt.xlabel('Time')
    plt.ylabel("Stoke Price Close (SGD)")
    plt.legend()
    plt.show()

# %%
t = scaler.inverse_transform(genting['Close'].values.reshape(-1,1)) 
p = scaler.inverse_transform(predictions)

# %%
t.shape, p.shape
# Out:
# ((1435, 1), (287, 1))

# %%
d = t.shape[0]-p.shape[0]
arr=np.full((d,1),np.nan)

# %%
r = np.concatenate((arr, p), axis=0)

# %%
plt.figure(figsize=(15,15))
plt.plot(genting['Date'], t.reshape(-1), label='Genting Sinagapore original', color='b')
plt.plot(genting['Date'], r.reshape(-1), label='Genting Sinagapore prediction', color='r')
plt.xlabel("Date")
plt.ylabel("Close Stoke Price (SGD)")
plt.legend()
plt.show();
